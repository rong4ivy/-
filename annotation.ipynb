# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.7.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (27 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.10-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.2.2 (from spacy)
#   Downloading thinc-8.2.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.4.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Downloading weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy) (2.7.3)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy) (24.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Downloading langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: numpy>=1.19.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy) (1.26.4)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading blis-0.7.11-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.2.2->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading cloudpathlib-0.18.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Downloading smart_open-7.0.4-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from jinja2->spacy) (2.1.5)
# Collecting marisa-trie>=0.7.7 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Downloading marisa_trie-1.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.7 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Using cached wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading spacy-3.7.5-cp312-cp312-macosx_11_0_arm64.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 605.8 kB/s eta 0:00:0000:0100:01
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp312-cp312-macosx_11_0_arm64.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 917.7 kB/s eta 0:00:00:01
# Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.0/182.0 kB 610.4 kB/s eta 0:00:00a 0:00:01
# Downloading murmurhash-1.0.10-cp312-cp312-macosx_11_0_arm64.whl (26 kB)
# Downloading preshed-3.0.9-cp312-cp312-macosx_11_0_arm64.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 kB 645.7 kB/s eta 0:00:00a 0:00:01
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp312-cp312-macosx_11_0_arm64.whl (486 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.4/486.4 kB 621.3 kB/s eta 0:00:00a 0:00:01
# Downloading thinc-8.2.5-cp312-cp312-macosx_11_0_arm64.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.6/760.6 kB 612.0 kB/s eta 0:00:0000:0100:01
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 918.2 kB/s eta 0:00:000:00:01
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.3/50.3 kB 568.0 kB/s eta 0:00:000:00:01
# Downloading blis-0.7.11-cp312-cp312-macosx_11_0_arm64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 610.8 kB/s eta 0:00:0000:0100:01
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading cloudpathlib-0.18.1-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 600.8 kB/s eta 0:00:0000:0100:01
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading marisa_trie-1.2.0-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.6/173.6 kB 618.2 kB/s eta 0:00:00a 0:00:01
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl (38 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wrapt, wasabi, spacy-loggers, spacy-legacy, shellingham, murmurhash, mdurl, marisa-trie, cloudpathlib, click, catalogue, blis, srsly, smart-open, preshed, markdown-it-py, language-data, rich, langcodes, confection, typer, thinc, weasel, spacy
# Successfully installed blis-0.7.11 catalogue-2.0.10 click-8.1.7 cloudpathlib-0.18.1 confection-0.1.5 cymem-2.0.8 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 preshed-3.0.9 rich-13.7.1 shellingham-1.5.4 smart-open-7.0.4 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 typer-0.12.3 wasabi-1.1.3 weasel-0.4.1 wrapt-1.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download zh_core_web_sm
# Out:
# Collecting zh-core-web-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/zh_core_web_sm-3.7.0/zh_core_web_sm-3.7.0-py3-none-any.whl (48.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 MB 592.4 kB/s eta 0:00:0000:0100:03
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from zh-core-web-sm==3.7.0) (3.7.5)
# Collecting spacy-pkuseg<0.1.0,>=0.0.27 (from zh-core-web-sm==3.7.0)
#   Downloading spacy_pkuseg-0.0.33-cp312-cp312-macosx_11_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.7.3)
# Requirement already satisfied: jinja2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/miniconda3/envs/dspy/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->zh-core-web-sm==3.7.0) (0.1.2)
# Downloading spacy_pkuseg-0.0.33-cp312-cp312-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 521.5 kB/s eta 0:00:0000:0100:01
# Installing collected packages: spacy-pkuseg, zh-core-web-sm
# Successfully installed spacy-pkuseg-0.0.33 zh-core-web-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('zh_core_web_sm')

# %%
import mobi
import json
import spacy
 
# Load Chinese language model
nlp = spacy.load("zh_core_web_sm")

def annotate_sentence(sentence):
    doc = nlp(sentence)
    
    segmentation = [token.text for token in doc]
    pos_tagging = [{"word": token.text, "pos": token.pos_} for token in doc]
    ner = [{"entity": ent.text, "type": ent.label_} for ent in doc.ents]
    
    dependency_parsing = {
        "type": "SD",
        "structure": [{"relation": token.dep_, "head": token.head.text, "dependent": token.text} for token in doc]
    }
    
    constituency_parsing = {
        "type": "Chinese Tree Bank",
        "structure": " ".join([token.text_with_ws for token in doc]) # Simulating TreeBank structure
    }
    
    semantic_dependency_analysis = [
        {"relation": token.dep_, "head": token.head.text, "dependent": token.text} for token in doc
    ]
    
    return {
        "sentence": sentence,
        "segmentation": segmentation,
        "pos_tagging": pos_tagging,
        "ner": ner,
        "dependency_parsing": dependency_parsing,
        "constituency_parsing": constituency_parsing,
        "semantic_dependency_analysis": semantic_dependency_analysis
    }

def process_text_file(file_path):
    with open(file_path, 'r') as f:
        content = f.read()
        half_length = len(content) // 3
        content = content[:half_length]
        doc = nlp(content)
        sentences = [sent.text for sent in doc.sents]
    
    annotations = [annotate_sentence(sentence.strip()) for sentence in sentences if sentence.strip()]
    
    return {"annotations": annotations}

# Replace with the path to your text file
file_path = "汪曾祺.txt"
annotations = process_text_file(file_path)

# Save annotations to a JSON file
output_file = "./汪曾祺_标注.json"
with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(annotations, f, ensure_ascii=False, indent=4)

print(f"Annotations saved to {output_file}")
# Out:
# Annotations saved to ./汪曾祺_标注.json

# %%
import json
import glob

# Define the path where your JSON files are located
path = "原创汉语/*.json"

# Initialize an empty list to store combined data
combined_data = []

# Iterate over all JSON files in the directory
for json_file in glob.glob(path):
    with open(json_file, 'r') as file:
        data = json.load(file)
        combined_data.extend(data)  # Assuming each JSON file contains a list of objects

# Write the combined data into a new JSON file
with open("combined.json", 'w') as output_file:
    json.dump(combined_data, output_file, indent=4)

print("All JSON files have been combined successfully into combined.json")
